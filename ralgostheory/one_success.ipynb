# %% [markdown]
# # Comparison of Amplification Methods based on One success

# %% [markdown]
# ## Problem Statement
#
# We have an algorithm $A$ for a decision problem with probability of success $p > 1/2$ for "true" inputs and $p=1$ for "false" inputs or $1/2$ for "false" and $1$ for "true". We want to amplify success rate of $A$ on inputs where it fails to $q > p$. We can achieve this by repeating algorithm $A$ with success rate of repeated algorithm given by various methods.

# %%
# importing libraries
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
from math import ceil, log, sqrt, exp
from scipy.stats import binom

# %% [markdown]
# ## Two Point Sampling
